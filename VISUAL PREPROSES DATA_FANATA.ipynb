# %%
pip install numpy pandas matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\ahadi\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\ahadi\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\ahadi\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\ahadi\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ahadi\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ahadi\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ahadi\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ahadi\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ahadi\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ahadi\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ahadi\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ahadi\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ahadi\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ahadi\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\ahadi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#IMPORT LIBRARY
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Membuat Bar Chart

# %%
MataKuliah = ['Dasar Pemrograman', 'Basis Data',
             'Machine Learning', 'Pemrograman Objek', 
             'Pemrograman Web']
Jumlah_mahasiswa = [125,90,120,99,77]

plt.figure(figsize=(22,7))
plt.barh(MataKuliah, Jumlah_mahasiswa, color='blue')
plt.title('Jumlah Mahasiswa pada matakuliah di semester 3', size=14)
plt.xlabel('Jumlah Mahasiswa', size=12)
plt.xticks(size=12)
plt.yticks(size=12)
plt.show()

# %% [markdown]
# ## Line Chart

# %%
#line chart 
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
Nilai = [80,90,65,75,79,82]
ax.plot(Nilai)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('equal')

stock = ['Cheese','Bread','Ice Cream','Noodles','Egg']
sold = [10,50,45,15,37,113]

ax.pie(sold, labels=stock, autopct='%1.2f%%')

plt.gca().set_aspect('equal', adjustable='box')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 10
#       7 stock = ['Cheese','Bread','Ice Cream','Noodles','Egg']
#       8 sold = [10,50,45,15,37,113]
# ---> 10 ax.pie(sold, labels=stock, autopct='%1.2f%%')
#      12 plt.gca().set_aspect('equal', adjustable='box')
#      14 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:3298, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3296     explode = [0] * len(x)
#    3297 if len(x) != len(labels):
# -> 3298     raise ValueError("'label' must be of length 'x'")
#    3299 if len(x) != len(explode):
#    3300     raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'

# %%
# Data untuk tiga kategori
akomodasi = [2000, 1100, 4180, 5800, 6420, 980]
kamar = [1503, 10732, 3555, 5206, 2187, 4731, 522]
kasur = [9257, 16415, 6045, 7832, 2885, 8080, 786]
 
# Membuat figure dan axis
fig, ax = plt.subplots(figsize=(8,6)) # Ukuran lebih jelas
 
# Membuat boxplot dengan berbagai pengaturan
box = ax.boxplot([akomodasi, kamar, kasur],
                 vert=False, # Membuat boxplot horizontal
                 showmeans=True, # Menampilkan nilai mean
                 meanline=True, # Menampilkan mean sebagai garis
                 tick_labels=['Akomodasi', 'Kamar', 'Kasur'], # Perbaikan: 'labels' → 'tick_labels'
                 patch_artist=True, # Memberikan warna pada boxplot
                 medianprops={'linewidth': 2, 'color': 'blue'}, # Warna garis median
                 meanprops={'linewidth': 2, 'color': 'red'}) # Warna garis mean
 
# Menambahkan warna untuk setiap box
colors = ['lightblue', 'lightgreen', 'lightcoral']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)
 
# Menyesuaikan aspek agar tidak terjadi peringatan
ax.set_aspect('auto')
 
# Menampilkan plot
plt.show()

# %% [markdown]
# ## Scatter PLOT

# %%
import matplotlib.pyplot as plt

# Data nilai tugas, UTS, dan UAS
tugas = [58, 80, 65, 79, 82]
uts = [78, 80, 85, 59, 92]
uas = [62, 79, 87, 77, 84]
 
# Membuat figure dan axis
fig, ax = plt.subplots()
 
# Scatter plot hubungan tugas dengan UTS
ax.scatter(tugas, uts, color='red', label='Tugas vs UTS')
# Scatter plot hubungan tugas dengan UAS
ax.scatter(tugas, uas, color='blue', label='Tugas vs UAS')
 
# Menambahkan label sumbu dan judul
tempX = 'Tugas'
tempY = 'Nilai'
ax.set_xlabel(tempX)
ax.set_ylabel(tempY)
ax.set_title('Scatter Plot')
 
# Menampilkan legenda
ax.legend()
 
# Menampilkan plot
plt.show()

# %%
# Mengisi nilai missing value dengan ketentuan:
# Modus untuk data kategorik dan mean untuk data numerik
 
from statistics import mode
 
# Menghitung modus untuk data kategorik
jenis_kelamin_mode = mode(df['jenis_kelamin'].dropna())
pekerjaan_mode = mode(df['pekerjaan'].dropna())
is_keturunan_mode = mode(df['is_keturunan'].dropna())
sampo_mode = mode(df['sampo'].dropna())
 
# Menghitung mean untuk data numerik
berat_mean = df['berat'].mean()
gaji_mean = df['gaji'].mean()
 
# Daftar kolom yang memiliki nilai missing
kolom_missing = ['jenis_kelamin', 'pekerjaan',
                 'is_keturunan', 'berat', 'sampo', 'gaji']
 
# Daftar nilai yang akan digunakan untuk mengisi missing values
inputan = [jenis_kelamin_mode, pekerjaan_mode,
           is_keturunan_mode, berat_mean, sampo_mode, gaji_mean]
 
# Mengisi nilai missing dengan metode yang benar
for kolom, nilai in zip(kolom_missing, inputan):
    df[kolom] = df[kolom].fillna(nilai)

# %%
df.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df.isna().sum()
#
# NameError: name 'df' is not defined
